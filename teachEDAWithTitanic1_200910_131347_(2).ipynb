# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharkarale/ML-assignments/blob/master/teachEDAWithTitanic1_200910_131347_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df= pd.read_csv('/content/Titanic/train.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x='Survived',data=df,hue='Sex')

# %%
sns.countplot(x='Survived',data=df)

# %%
sns.lineplot(x='Age',y='Fare',data=df)

# %%
df.plot.scatter('Age','Fare')

# %%
df.plot.scatter('Age','Survived')

# %%
df['Age'].hist(bins=8)

# %%
import matplotlib.pyplot as plt
sizes= df['Survived'].value_counts()
fig1,ax1 = plt.subplots()
ax1.pie(sizes,labels=['Not Survived','Survived'],autopct='%1.1f%%',shadow=True)
plt.show()
